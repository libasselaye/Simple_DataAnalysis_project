# %% [markdown]
# # Setting up work environment

# %%
import os
import pandas as pd
from datetime import datetime
import numpy as np
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
#Je me positionne dans le dossier contenant les données
os.chdir('/content/drive/MyDrive/Python_Projet_Healthy/data')

#Je liste le contenu du dossier
os.listdir()
# Out:
# ['008ViYv',
#  '004RoMa',
#  '010AlCo',
#  '011DeVi',
#  '020LeMa',
#  '016GiMa',
#  '012GuNi',
#  '006MuCa',
#  '002VaAl',
#  '017BoAr',
#  '014MoMa',
#  '019LeGe',
#  '007CaMa',
#  '003LaRo',
#  '001MoDe',
#  '005HoRo',
#  '018ViJe',
#  '013JoGe',
#  '015GiRi',
#  'dataset_final (1).gsheet',
#  'participants.csv',
#  'dataset_final.csv',
#  'dataset_final.gsheet']

# %%
os.listdir()
# Out:
# ['008ViYv',
#  '004RoMa',
#  '010AlCo',
#  '011DeVi',
#  '020LeMa',
#  '016GiMa',
#  '012GuNi',
#  '006MuCa',
#  '002VaAl',
#  '017BoAr',
#  '014MoMa',
#  '019LeGe',
#  '007CaMa',
#  '003LaRo',
#  '001MoDe',
#  '005HoRo',
#  '018ViJe',
#  '013JoGe',
#  '015GiRi',
#  'dataset_final (1).gsheet',
#  'participants.csv',
#  'dataset_final.csv',
#  'dataset_final.gsheet']

# %%
#!pip install pip==21.3.1

# %%
#!python -m pip install mitosheet

# %%
#import mitosheet
#mitosheet.sheet()

# %% [markdown]
# # Precise Import Dominante Marker Filer

# %%
# Paramater Explain
# on_bad_lines for skipp Error tokenizing data
dominante_marker = pd.read_csv('001MoDe/dominante1.marker.csv', on_bad_lines='skip', skiprows=17, delimiter=',')

# %%
dominante_marker
# Out:
#        Var    nLaps         Re         Te      error     MT/lap    IDe/lap   \
# 0     unit      lap      pixel      pixel          %      s/lap    bit/lap
# 1   Theory     1.00     209.50      47.00       3.88
# 2   Rec001   -10.85     213.87      91.79       3.90       1.84      14.64
# 3   Rec002   -11.97     209.85      34.46       0.74       1.59      38.27
# 4   Rec003   -13.26     209.43      42.42       2.81       1.45      31.02
# 5   Rec004   -12.83     209.46      37.14       0.13       1.49      35.43
# 6   Rec005   -14.74     210.89      43.88       2.84       1.30      30.20
# 7   Rec006     0.00       0.00       0.00        NaN        NaN        NaN
#
#          Be        IPe   Unnamed: 9
# 0    double      bit/s          NaN
# 1      1.00                     NaN
# 2      1.95       7.94          NaN
# 3      0.73      24.04          NaN
# 4      0.90      21.40          NaN
# 5      0.79      23.72          NaN
# 6      0.93      23.20          NaN
# ...

# %%
# Deleting the two first rows and the 'Unnamed: 9' column
dominante_marker.drop(dominante_marker.index[:2], inplace=True)
dominante_marker
# Out:
#        Var    nLaps         Re         Te      error     MT/lap    IDe/lap   \
# 2   Rec001   -10.85     213.87      91.79       3.90       1.84      14.64
# 3   Rec002   -11.97     209.85      34.46       0.74       1.59      38.27
# 4   Rec003   -13.26     209.43      42.42       2.81       1.45      31.02
# 5   Rec004   -12.83     209.46      37.14       0.13       1.49      35.43
# 6   Rec005   -14.74     210.89      43.88       2.84       1.30      30.20
# 7   Rec006     0.00       0.00       0.00        NaN        NaN        NaN
#
#          Be        IPe   Unnamed: 9
# 2      1.95       7.94          NaN
# 3      0.73      24.04          NaN
# 4      0.90      21.40          NaN
# 5      0.79      23.72          NaN
# 6      0.93      23.20          NaN
# 7      0.00       0.00          NaN

# %%
dominante_marker.drop(columns=['Unnamed: 9'], inplace=True)
dominante_marker
# Out:
#        Var    nLaps         Re         Te      error     MT/lap    IDe/lap   \
# 2   Rec001   -10.85     213.87      91.79       3.90       1.84      14.64
# 3   Rec002   -11.97     209.85      34.46       0.74       1.59      38.27
# 4   Rec003   -13.26     209.43      42.42       2.81       1.45      31.02
# 5   Rec004   -12.83     209.46      37.14       0.13       1.49      35.43
# 6   Rec005   -14.74     210.89      43.88       2.84       1.30      30.20
# 7   Rec006     0.00       0.00       0.00        NaN        NaN        NaN
#
#          Be        IPe
# 2      1.95       7.94
# 3      0.73      24.04
# 4      0.90      21.40
# 5      0.79      23.72
# 6      0.93      23.20
# 7      0.00       0.00

# %% [markdown]
# # Precise Import Non Dominante Marker File

# %%
# Paramater Explain
# on_bad_lines for skipp Error tokenizing data
nondominante_marker = pd.read_csv('001MoDe/nondominante1.marker.csv', on_bad_lines='skip', skiprows=17, delimiter=',')
nondominante_marker.drop(nondominante_marker.index[:2], inplace=True)
nondominante_marker.drop(columns=['Unnamed: 9'], inplace=True)

# %%
nondominante_marker
# Out:
#        Var    nLaps         Re         Te      error     MT/lap    IDe/lap   \
# 2   Rec001   -11.79     214.80      43.57       4.42       1.65      30.98
# 3   Rec002   -10.63     208.90      55.92       7.91       1.81      23.47
# 4   Rec003    -9.61     212.54      44.85       3.45       1.94      29.77
# 5   Rec004   -10.28     209.85      46.42       3.49       1.86      28.41
# 6   Rec005    -9.96     209.77      42.72       1.79       1.88      30.85
# 7   Rec006     0.00       0.00       0.00        NaN        NaN        NaN
#
#          Be        IPe
# 2      0.93      18.73
# 3      1.19      12.95
# 4      0.95      15.33
# 5      0.99      15.28
# 6      0.91      16.41
# 7      0.00       0.00

# %% [markdown]
# # Suppress all the familiarisation Files

# %%
df = pd.read_csv('participants.csv')

# %%
# Path to the main directory containing participant folders
main_directory = '/content/drive/MyDrive/Python_Projet_Healthy/data'

# Iterate through each row of the DataFrame
for index, row in df.iterrows():
    participant_id = row['identifier']

    # Path to the participant's folder
    participant_directory = os.path.join(main_directory, str(participant_id))

    # Check if the participant's folder exists
    if os.path.exists(participant_directory):
        # List of files in the participant's folder
        files_in_directory = os.listdir(participant_directory)

        # Iterate through all files in the participant's folder
        for filename in files_in_directory:
            # Check if the file name starts with "familiarisation"
            if filename.startswith("familiarisation"):
                file_path = os.path.join(participant_directory, filename)

                # Delete the file
                os.remove(file_path)
                print(f"Le fichier {filename} a été supprimé.")

    else:
        print(f"Dossier du participant {participant_id} introuvable.")
# Out:
# Le fichier familiarisationdominante.marker.csv a été supprimé.
# Le fichier familiarisationnondominante.marker.csv a été supprimé.
# Le fichier familiarisationdominante.marker.csv a été supprimé.
# Le fichier familiarisationnondominante.marker.csv a été supprimé.
# Le fichier familiarisationdominante.marker.csv a été supprimé.
# Le fichier familiarisationnondominante.marker.csv a été supprimé.
# Le fichier familiarisationnondominante.marker.csv a été supprimé.
# Le fichier familiarisationdominante.marker.csv a été supprimé.
# Le fichier familiarisationnondominante.marker.csv a été supprimé.
# Dossier du participant 009BoAl introuvable.
# Le fichier familiarisationdominante.marker.csv a été supprimé.
# Le fichier familiarisationnondominante.marker.csv a été supprimé.
# Le fichier familiarisationdominante.marker.csv a été supprimé.
# Le fichier familiarisationnondominante.marker.csv a été supprimé.
# Le fichier familiarisationdominante.marker.csv a été supprimé.
# ...

# %% [markdown]
# # Automatic Importation

# %%
# Lire le fichier participants.csv
participants_df = pd.read_csv('participants.csv')
participants = participants_df['identifier'].to_list()
participants
# Out:
# ['001MoDe',
#  '002VaAl',
#  '003LaRo',
#  '004RoMa',
#  '005HoRo',
#  '006MuCa',
#  '007CaMa',
#  '008ViYv',
#  '009BoAl',
#  '010AlCo',
#  '011DeVi',
#  '012GuNi',
#  '013JoGe',
#  '014MoMa',
#  '015GiRi',
#  '016GiMa',
#  '017BoAr',
#  '018ViJe',
#  '019LeGe',
#  '020LeMa']

# %%
participants_df
# Out:
#    identifier Gender    handedness class age   started hand  inclusion date  \
# 0     001MoDe      M         right    [55-64]      dominant      26/03/2021
# 1     002VaAl      M         right    [55-64]   non dominant     06/03/2021
# 2     003LaRo      F         right    [75-84]      dominant      07/04/2021
# 3     004RoMa      F         right    [65-74]   non dominant     07/04/2021
# 4     005HoRo      M         right    [75-84]      dominant      07/04/2021
# 5     006MuCa      F         right     [0-34]  non dominant      08/04/2021
# 6     007CaMa      F         right    [65-74]      dominant      08/04/2021
# 7     008ViYv      F         right    [75-84]  non dominant      08/04/2021
# 8     009BoAl      M          left    [75-84]      dominant      09/04/2021
# 9     010AlCo      F         right    [65-74]  non dominant      13/04/2021
# 10    011DeVi      M         right    [55-64]      dominant      13/04/2021
# ...

# %%
# Path to the main directory containing participant folders
main_directory = '/content/drive/MyDrive/Python_Projet_Healthy/data'

# %%
#'    Var '
#'     IPe '
# Create an empty DataFrame to store data from dominant and non-dominant files
combined_data = []

# Iterate through each participant
for index, row in participants_df.iterrows():
    participant_id = row['identifier']

    # Dictionary to store participant data
    participant_data = {'identifier': [], 'VAR': [], 'Ipe': [], 'filesource': []}

    # Participant directory path
    participant_directory = os.path.join(main_directory, str(participant_id))

    # Check if participant directory exists
    if os.path.exists(participant_directory):
        # Iterate through files in participant directory
        for file in os.listdir(participant_directory):
            if file.endswith('.marker.csv'):
                # Full file path
                file_path = os.path.join(participant_directory, file)

                # Read the file
                file_df = pd.read_csv(file_path, on_bad_lines='skip', skiprows=17, delimiter=',')
                file_df.drop(file_df.index[:2], inplace=True)
                file_df = file_df.iloc[:,:-1]

                # Check if 'Var' and 'Ipe' columns exist in the file
                if '    Var ' in file_df.columns and '     IPe ' in file_df.columns:
                    # Add data to DataFrame
                    data = file_df[['    Var ', '     IPe ']]
                    data['filesource'] = file
                    data['identifier'] = participant_id
                    combined_data.append(data)
                else:
                    print(f"Columns 'Var' and 'Ipe' are not present in file {file}.")
    else:
        print(f"Participant directory {participant_id} not found.")

# Concatenate all data into a single DataFrame
combined_data_df = pd.concat(combined_data, ignore_index=True)

# Merge data with 'participants.csv' DataFrame
result_df = pd.merge(participants_df, combined_data_df, on='identifier', how='left')
# Out:
# <ipython-input-29-87d7a52cff38>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['filesource'] = file
# <ipython-input-29-87d7a52cff38>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['identifier'] = participant_id
# <ipython-input-29-87d7a52cff38>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
result_df
# Out:
#     identifier Gender handedness class age   started hand  inclusion date  \
# 0      001MoDe      M      right    [55-64]      dominant      26/03/2021
# 1      001MoDe      M      right    [55-64]      dominant      26/03/2021
# 2      001MoDe      M      right    [55-64]      dominant      26/03/2021
# 3      001MoDe      M      right    [55-64]      dominant      26/03/2021
# 4      001MoDe      M      right    [55-64]      dominant      26/03/2021
# ..         ...    ...        ...        ...            ...            ...
# 434    020LeMa      F      right    [65-74]  non dominant      19/04/2021
# 435    020LeMa      F      right    [65-74]  non dominant      19/04/2021
# 436    020LeMa      F      right    [65-74]  non dominant      19/04/2021
# 437    020LeMa      F      right    [65-74]  non dominant      19/04/2021
# 438    020LeMa      F      right    [65-74]  non dominant      19/04/2021
#
#     birth date (month/years)      Var        IPe              filesource
# ...

# %%
dataset = result_df
dataset
# Out:
#     identifier Gender handedness class age   started hand  inclusion date  \
# 0      001MoDe      M      right    [55-64]      dominant      26/03/2021
# 1      001MoDe      M      right    [55-64]      dominant      26/03/2021
# 2      001MoDe      M      right    [55-64]      dominant      26/03/2021
# 3      001MoDe      M      right    [55-64]      dominant      26/03/2021
# 4      001MoDe      M      right    [55-64]      dominant      26/03/2021
# ..         ...    ...        ...        ...            ...            ...
# 434    020LeMa      F      right    [65-74]  non dominant      19/04/2021
# 435    020LeMa      F      right    [65-74]  non dominant      19/04/2021
# 436    020LeMa      F      right    [65-74]  non dominant      19/04/2021
# 437    020LeMa      F      right    [65-74]  non dominant      19/04/2021
# 438    020LeMa      F      right    [65-74]  non dominant      19/04/2021
#
#     birth date (month/years)      Var        IPe              filesource
# ...

# %%
result_df.to_csv('dataset_final.csv')
